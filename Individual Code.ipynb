# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2022-04-23 22:16:46--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   176MB/s    in 0.5s
#
# 2022-04-23 22:16:47 (176 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
#     - cryptography==2.8=py38h1ba5d50_0
#     - idna==2.8=py38_1000
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py38_1
#     - pycosat==0.6.3=py38h7b6447c_0
#     - pycparser==2.19=py_0
#     - pyopenssl==19.1.0=py38_0
#     - pysocks==1.7.1=py38_0
#     - python==3.8.1=h0371630_1
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py38_1
#     - ruamel_yaml==0.15.87=py38h7b6447c_0
#     - setuptools==45.2.0=py38_0
#     - six==1.14.0=py38_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py38_0
#     - wheel==0.34.2=py38_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py38_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py38_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py38h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py38_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py38_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py38h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py38h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py38_1000
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py38_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py38h7b6447c_0
#   pycparser          pkgs/main/noarch::pycparser-2.19-py_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py38_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38_0
#   python             pkgs/main/linux-64::python-3.8.1-h0371630_1
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py38_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py38h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py38_0
#   six                pkgs/main/linux-64::six-1.14.0-py38_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py38_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py38_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            1_gnu          22 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py38h7f8727e_0          33 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     beautifulsoup4-4.11.1      |   py38h06a4308_0         185 KB
#     bleach-4.1.0               |     pyhd3eb1b0_0         123 KB
#     ca-certificates-2022.3.29  |       h06a4308_1         122 KB
#     certifi-2021.10.8          |   py38h06a4308_2         152 KB
#     conda-4.12.0               |   py38h06a4308_0        14.5 MB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     debugpy-1.5.1              |   py38h295c915_0         1.7 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          23 KB
#     entrypoints-0.4            |   py38h06a4308_0          16 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     expat-2.4.4                |       h295c915_0         169 KB
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
#     freetype-2.11.0            |       h70c0345_0         618 KB
#     glib-2.69.1                |       h4ff587b_1         1.7 MB
#     gst-plugins-base-1.14.0    |       h8213a91_2         4.9 MB
#     gstreamer-1.14.0           |       h28cd5cc_2         3.2 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     ipykernel-6.9.1            |   py38h06a4308_0         199 KB
#     ipython-8.2.0              |   py38h06a4308_0         993 KB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     ipywidgets-7.6.5           |     pyhd3eb1b0_1         105 KB
#     jedi-0.18.1                |   py38h06a4308_1         982 KB
#     jinja2-3.0.3               |     pyhd3eb1b0_0         106 KB
#     jpeg-9d                    |       h7f8727e_0         232 KB
#     jsonschema-4.4.0           |   py38h06a4308_0         121 KB
#     jupyter-1.0.0              |           py38_7           7 KB
#     jupyter_client-7.2.2       |   py38h06a4308_0         191 KB
#     jupyter_console-6.4.3      |     pyhd3eb1b0_0          23 KB
#     jupyter_core-4.9.2         |   py38h06a4308_0          79 KB
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     libgcc-ng-9.3.0            |      h5101ec6_17         4.8 MB
#     libgomp-9.3.0              |      h5101ec6_17         311 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     libuuid-1.0.3              |       h7f8727e_2          17 KB
#     libxcb-1.14                |       h7b6447c_0         505 KB
#     libxml2-2.9.12             |       h03d6c58_0         1.2 MB
#     markupsafe-2.0.1           |   py38h27cfd23_0          22 KB
#     matplotlib-inline-0.1.2    |     pyhd3eb1b0_2          12 KB
#     mistune-0.8.4              |py38h7b6447c_1000          55 KB
#     nbclient-0.5.13            |   py38h06a4308_0          91 KB
#     nbconvert-6.4.4            |   py38h06a4308_0         494 KB
#     nbformat-5.3.0             |   py38h06a4308_0         129 KB
#     nest-asyncio-1.5.5         |   py38h06a4308_0          16 KB
#     notebook-6.4.8             |   py38h06a4308_0         4.2 MB
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     prometheus_client-0.13.1   |     pyhd3eb1b0_0          47 KB
#     prompt-toolkit-3.0.20      |     pyhd3eb1b0_0         259 KB
#     prompt_toolkit-3.0.20      |       hd3eb1b0_0          12 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.11.2            |     pyhd3eb1b0_0         759 KB
#     pyparsing-3.0.4            |     pyhd3eb1b0_0          81 KB
#     pyqt-5.9.2                 |   py38h05f1152_4         4.5 MB
#     pyrsistent-0.18.0          |   py38heee7806_0          94 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     python-fastjsonschema-2.15.1|     pyhd3eb1b0_0          29 KB
#     pyzmq-22.3.0               |   py38h295c915_2         476 KB
#     qt-5.9.7                   |       h5867ecd_1        68.5 MB
#     qtconsole-5.3.0            |     pyhd3eb1b0_0          93 KB
#     qtpy-2.0.1                 |     pyhd3eb1b0_0          40 KB
#     send2trash-1.8.0           |     pyhd3eb1b0_1          19 KB
#     sip-4.19.13                |   py38h295c915_0         279 KB
#     soupsieve-2.3.1            |     pyhd3eb1b0_0          34 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     terminado-0.13.1           |   py38h06a4308_0          30 KB
#     testpath-0.5.0             |     pyhd3eb1b0_0          81 KB
#     tornado-6.1                |   py38h27cfd23_0         588 KB
#     traitlets-5.1.1            |     pyhd3eb1b0_0          84 KB
#     typing-extensions-4.1.1    |       hd3eb1b0_0           8 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     webencodings-0.5.1         |           py38_1          20 KB
#     widgetsnbextension-3.5.2   |   py38h06a4308_0         651 KB
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     zeromq-4.3.4               |       h2531618_0         331 KB
#     zipp-3.7.0                 |     pyhd3eb1b0_0          12 KB
#     ------------------------------------------------------------
#                                            Total:       134.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   argon2-cffi        pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ pkgs/main/linux-64::argon2-cffi-bindings-21.2.0-py38h7f8727e_0
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3eb1b0_0
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.11.1-py38h06a4308_0
#   bleach             pkgs/main/noarch::bleach-4.1.0-pyhd3eb1b0_0
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   debugpy            pkgs/main/linux-64::debugpy-1.5.1-py38h295c915_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         pkgs/main/noarch::defusedxml-0.7.1-pyhd3eb1b0_0
#   entrypoints        pkgs/main/linux-64::entrypoints-0.4-py38h06a4308_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   expat              pkgs/main/linux-64::expat-2.4.4-h295c915_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.1-h6c09931_0
#   freetype           pkgs/main/linux-64::freetype-2.11.0-h70c0345_0
#   glib               pkgs/main/linux-64::glib-2.69.1-h4ff587b_1
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.0-h8213a91_2
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.0-h28cd5cc_2
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   ipykernel          pkgs/main/linux-64::ipykernel-6.9.1-py38h06a4308_0
#   ipython            pkgs/main/linux-64::ipython-8.2.0-py38h06a4308_0
#   ipython_genutils   pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets         pkgs/main/noarch::ipywidgets-7.6.5-pyhd3eb1b0_1
#   jedi               pkgs/main/linux-64::jedi-0.18.1-py38h06a4308_1
#   jinja2             pkgs/main/noarch::jinja2-3.0.3-pyhd3eb1b0_0
#   jpeg               pkgs/main/linux-64::jpeg-9d-h7f8727e_0
#   jsonschema         pkgs/main/linux-64::jsonschema-4.4.0-py38h06a4308_0
#   jupyter            pkgs/main/linux-64::jupyter-1.0.0-py38_7
#   jupyter_client     pkgs/main/linux-64::jupyter_client-7.2.2-py38h06a4308_0
#   jupyter_console    pkgs/main/noarch::jupyter_console-6.4.3-pyhd3eb1b0_0
#   jupyter_core       pkgs/main/linux-64::jupyter_core-4.9.2-py38h06a4308_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h7f8727e_2
#   libxcb             pkgs/main/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.12-h03d6c58_0
#   markupsafe         pkgs/main/linux-64::markupsafe-2.0.1-py38h27cfd23_0
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0.1.2-pyhd3eb1b0_2
#   mistune            pkgs/main/linux-64::mistune-0.8.4-py38h7b6447c_1000
#   nbclient           pkgs/main/linux-64::nbclient-0.5.13-py38h06a4308_0
#   nbconvert          pkgs/main/linux-64::nbconvert-6.4.4-py38h06a4308_0
#   nbformat           pkgs/main/linux-64::nbformat-5.3.0-py38h06a4308_0
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.5.5-py38h06a4308_0
#   notebook           pkgs/main/linux-64::notebook-6.4.8-py38h06a4308_0
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd3eb1b0_0
#   pandocfilters      pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb1b0_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   prometheus_client  pkgs/main/noarch::prometheus_client-0.13.1-pyhd3eb1b0_0
#   prompt-toolkit     pkgs/main/noarch::prompt-toolkit-3.0.20-pyhd3eb1b0_0
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.20-hd3eb1b0_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pygments           pkgs/main/noarch::pygments-2.11.2-pyhd3eb1b0_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyhd3eb1b0_0
#   pyqt               pkgs/main/linux-64::pyqt-5.9.2-py38h05f1152_4
#   pyrsistent         pkgs/main/linux-64::pyrsistent-0.18.0-py38heee7806_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python-fastjsonsc~ pkgs/main/noarch::python-fastjsonschema-2.15.1-pyhd3eb1b0_0
#   pyzmq              pkgs/main/linux-64::pyzmq-22.3.0-py38h295c915_2
#   qt                 pkgs/main/linux-64::qt-5.9.7-h5867ecd_1
#   qtconsole          pkgs/main/noarch::qtconsole-5.3.0-pyhd3eb1b0_0
#   qtpy               pkgs/main/noarch::qtpy-2.0.1-pyhd3eb1b0_0
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-pyhd3eb1b0_1
#   sip                pkgs/main/linux-64::sip-4.19.13-py38h295c915_0
#   soupsieve          pkgs/main/noarch::soupsieve-2.3.1-pyhd3eb1b0_0
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   terminado          pkgs/main/linux-64::terminado-0.13.1-py38h06a4308_0
#   testpath           pkgs/main/noarch::testpath-0.5.0-pyhd3eb1b0_0
#   tornado            pkgs/main/linux-64::tornado-6.1-py38h27cfd23_0
#   traitlets          pkgs/main/noarch::traitlets-5.1.1-pyhd3eb1b0_0
#   typing-extensions  pkgs/main/noarch::typing-extensions-4.1.1-hd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-4.1.1-pyh06a4308_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       pkgs/main/linux-64::webencodings-0.5.1-py38_1
#   widgetsnbextension pkgs/main/linux-64::widgetsnbextension-3.5.2-py38h06a4308_0
#   zeromq             pkgs/main/linux-64::zeromq-4.3.4-h2531618_0
#   zipp               pkgs/main/noarch::zipp-3.7.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2022.3.29-h06a4308_1
#   certifi                                 2019.11.28-py38_0 --> 2021.10.8-py38h06a4308_2
#   conda                                        4.8.2-py38_0 --> 4.12.0-py38h06a4308_0
#   libffi                                   3.2.1-hd88cf55_4 --> 3.3-he6710b0_2
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 9.3.0-h5101ec6_17
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1n-h7f8727e_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.5-h7b6447c_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - google-colab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.7.4.post0        |   py38h7f8727e_2         553 KB
#     async-timeout-3.0.1        |          py_1000          11 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     cachetools-5.0.0           |     pyhd8ed1ab_0          12 KB  conda-forge
#     certifi-2021.10.8          |   py38h578d9bd_2         145 KB  conda-forge
#     conda-4.12.0               |   py38h578d9bd_0         1.0 MB  conda-forge
#     cryptography-35.0.0        |   py38ha5dfef3_0         1.5 MB  conda-forge
#     google-auth-2.6.6          |     pyh6c4a22f_0          84 KB  conda-forge
#     google-colab-1.0.0         |     pyh44b312d_0          77 KB  conda-forge
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     libgfortran-ng-11.2.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-11.2.0        |      h5c6108e_16         1.7 MB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     multidict-5.2.0            |   py38h7f8727e_2          64 KB
#     numpy-1.20.3               |   py38h9894fe3_1         5.8 MB  conda-forge
#     pandas-1.0.5               |   py38hcb8c335_0        10.5 MB  conda-forge
#     portpicker-1.3.1           |   py38h06a4308_0         260 KB
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_0          49 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     pytz-2022.1                |     pyhd8ed1ab_0         242 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     rsa-4.8                    |     pyhd8ed1ab_0          31 KB  conda-forge
#     yarl-1.6.3                 |   py38h27cfd23_0         136 KB
#     ------------------------------------------------------------
#                                            Total:        31.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            pkgs/main/linux-64::aiohttp-3.7.4.post0-py38h7f8727e_2
#   async-timeout      conda-forge/noarch::async-timeout-3.0.1-py_1000
#   cachetools         conda-forge/noarch::cachetools-5.0.0-pyhd8ed1ab_0
#   google-auth        conda-forge/noarch::google-auth-2.6.6-pyh6c4a22f_0
#   google-colab       conda-forge/noarch::google-colab-1.0.0-pyh44b312d_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-11_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-11_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.2.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.2.0-h5c6108e_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-11_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   multidict          pkgs/main/linux-64::multidict-5.2.0-py38h7f8727e_2
#   numpy              conda-forge/linux-64::numpy-1.20.3-py38h9894fe3_1
#   pandas             conda-forge/linux-64::pandas-1.0.5-py38hcb8c335_0
#   portpicker         pkgs/main/linux-64::portpicker-1.3.1-py38h06a4308_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#   pytz               conda-forge/noarch::pytz-2022.1-pyhd8ed1ab_0
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.8-pyhd8ed1ab_0
#   yarl               pkgs/main/linux-64::yarl-1.6.3-py38h27cfd23_0
#
# The following packages will be UPDATED:
#
#   cryptography       pkgs/main::cryptography-2.8-py38h1ba5~ --> conda-forge::cryptography-35.0.0-py38ha5dfef3_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-~ --> conda-forge/noarch::pyopenssl-22.0.0-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.3.29-~ --> conda-forge::ca-certificates-2021.10.8-ha878542_0
#   certifi            pkgs/main::certifi-2021.10.8-py38h06a~ --> conda-forge::certifi-2021.10.8-py38h578d9bd_2
#   conda              pkgs/main::conda-4.12.0-py38h06a4308_0 --> conda-forge::conda-4.12.0-py38h578d9bd_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installed kernelspec py38 in /root/.local/share/jupyter/kernels/py38

# %%
# !pip install numpy
# !pip install gym
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/site-packages (1.20.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.8/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/site-packages (from gym) (1.20.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/site-packages (from gym) (2.0.0)

# %%
# !pip install -U tensorboardx
# Out:
# Requirement already up-to-date: tensorboardx in /usr/local/lib/python3.8/site-packages (2.5)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.8/site-packages (from tensorboardx) (1.20.3)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.8/site-packages (from tensorboardx) (1.14.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.8/site-packages (from tensorboardx) (3.20.1)

# %%
# !pip install -U "ray[tune]"
# !pip install -U "ray[rllib]"
# !pip install -U "ray[serve]"
# Out:
# Requirement already up-to-date: ray[tune] in /usr/local/lib/python3.8/site-packages (1.12.0)
# Requirement already satisfied, skipping upgrade: attrs in /usr/local/lib/python3.8/site-packages (from ray[tune]) (21.4.0)
# Requirement already satisfied, skipping upgrade: aiosignal in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.2.0)
# Requirement already satisfied, skipping upgrade: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.43.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.8/site-packages (from ray[tune]) (8.1.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.15.3 in /usr/local/lib/python3.8/site-packages (from ray[tune]) (3.20.1)
# Requirement already satisfied, skipping upgrade: frozenlist in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.3.0)
# Requirement already satisfied, skipping upgrade: virtualenv in /usr/local/lib/python3.8/site-packages (from ray[tune]) (20.14.1)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.8/site-packages (from ray[tune]) (4.4.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.8/site-packages (from ray[tune]) (2.22.0)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.8/site-packages (from ray[tune]) (3.6.0)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.8/site-packages (from ray[tune]) (6.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.16; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.20.3)
# Collecting tabulate; extra == "tune"
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting tensorboardX>=1.9; extra == "tune"
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.6 MB/s
# Requirement already satisfied, skipping upgrade: pandas; extra == "tune" in /usr/local/lib/python3.8/site-packages (from ray[tune]) (1.0.5)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.8/site-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]) (1.14.0)
# Requirement already satisfied, skipping upgrade: platformdirs<3,>=2 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[tune]) (2.5.2)
# Requirement already satisfied, skipping upgrade: distlib<1,>=0.3.1 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[tune]) (0.3.4)
# Requirement already satisfied, skipping upgrade: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[tune]) (0.18.0)
# Requirement already satisfied, skipping upgrade: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[tune]) (5.2.0)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests->ray[tune]) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests->ray[tune]) (1.25.8)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests->ray[tune]) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests->ray[tune]) (2021.10.8)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "tune"->ray[tune]) (2022.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "tune"->ray[tune]) (2.8.2)
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->ray[tune]) (3.7.0)
# Installing collected packages: tabulate, tensorboardX
# Successfully installed tabulate-0.8.9 tensorboardX-2.5
# Requirement already up-to-date: ray[rllib] in /usr/local/lib/python3.8/site-packages (1.12.0)
# Requirement already satisfied, skipping upgrade: aiosignal in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.2.0)
# Requirement already satisfied, skipping upgrade: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.43.0)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.0.3)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (3.6.0)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (4.4.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.15.3 in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (3.20.1)
# Requirement already satisfied, skipping upgrade: attrs in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (21.4.0)
# Requirement already satisfied, skipping upgrade: frozenlist in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.3.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (8.1.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (6.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.16; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.20.3)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (2.22.0)
# Requirement already satisfied, skipping upgrade: virtualenv in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (20.14.1)
# Requirement already satisfied, skipping upgrade: tabulate; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (0.8.9)
# Collecting scikit-image; extra == "rllib"
#   Downloading scikit_image-0.19.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 4.4 MB/s
# Requirement already satisfied, skipping upgrade: tensorboardX>=1.9; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (2.5)
# Collecting gym<0.22; extra == "rllib"
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 39.5 MB/s
# Collecting lz4; extra == "rllib"
#   Downloading lz4-4.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 35.5 MB/s
# Collecting scipy; extra == "rllib"
#   Downloading scipy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      |████████████████████████████████| 41.6 MB 1.3 MB/s
# Collecting dm-tree; extra == "rllib"
#   Downloading dm_tree-0.1.7-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 58.4 MB/s
# Collecting matplotlib!=3.4.3; extra == "rllib"
#   Downloading matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 36.8 MB/s
# Requirement already satisfied, skipping upgrade: pandas; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]) (1.0.5)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.8/site-packages (from grpcio<=1.43.0,>=1.28.1->ray[rllib]) (1.14.0)
# Requirement already satisfied, skipping upgrade: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]) (0.18.0)
# Requirement already satisfied, skipping upgrade: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]) (5.2.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests->ray[rllib]) (2021.10.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests->ray[rllib]) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests->ray[rllib]) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests->ray[rllib]) (1.25.8)
# Requirement already satisfied, skipping upgrade: platformdirs<3,>=2 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[rllib]) (2.5.2)
# Requirement already satisfied, skipping upgrade: distlib<1,>=0.3.1 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[rllib]) (0.3.4)
# Collecting networkx>=2.2
#   Downloading networkx-2.8-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 27.9 MB/s
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 29.8 MB/s
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.4.22-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 51.9 MB/s
# Collecting imageio>=2.4.1
#   Downloading imageio-2.17.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 46.4 MB/s
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]) (21.3)
# Collecting pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0
#   Downloading Pillow-9.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 36.9 MB/s
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.3 MB/s
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (3.0.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.2-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 52.3 MB/s
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "rllib"->ray[rllib]) (2022.1)
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->ray[rllib]) (3.7.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616824 sha256=a23552b11a652b06a7f23a8c5b37fb349bb6f1d8715f4cd08f37d2dc30668a99
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# Installing collected packages: networkx, PyWavelets, scipy, tifffile, pillow, imageio, scikit-image, cloudpickle, gym, lz4, dm-tree, cycler, kiwisolver, fonttools, matplotlib
# Successfully installed PyWavelets-1.3.0 cloudpickle-2.0.0 cycler-0.11.0 dm-tree-0.1.7 fonttools-4.33.2 gym-0.21.0 imageio-2.17.0 kiwisolver-1.4.2 lz4-4.0.0 matplotlib-3.5.1 networkx-2.8 pillow-9.1.0 scikit-image-0.19.2 scipy-1.8.0 tifffile-2022.4.22
# Requirement already up-to-date: ray[serve] in /usr/local/lib/python3.8/site-packages (1.12.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.8/site-packages (from ray[serve]) (8.1.2)
# Requirement already satisfied, skipping upgrade: attrs in /usr/local/lib/python3.8/site-packages (from ray[serve]) (21.4.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.8/site-packages (from ray[serve]) (2.22.0)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.8/site-packages (from ray[serve]) (4.4.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.8/site-packages (from ray[serve]) (6.0)
# Requirement already satisfied, skipping upgrade: virtualenv in /usr/local/lib/python3.8/site-packages (from ray[serve]) (20.14.1)
# Requirement already satisfied, skipping upgrade: aiosignal in /usr/local/lib/python3.8/site-packages (from ray[serve]) (1.2.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.15.3 in /usr/local/lib/python3.8/site-packages (from ray[serve]) (3.20.1)
# Requirement already satisfied, skipping upgrade: frozenlist in /usr/local/lib/python3.8/site-packages (from ray[serve]) (1.3.0)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.8/site-packages (from ray[serve]) (3.6.0)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from ray[serve]) (1.0.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.16; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from ray[serve]) (1.20.3)
# Requirement already satisfied, skipping upgrade: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.8/site-packages (from ray[serve]) (1.43.0)
# Collecting aiorwlock; extra == "serve"
#   Downloading aiorwlock-1.3.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied, skipping upgrade: prometheus-client<0.14.0,>=0.7.1; extra == "serve" in /usr/local/lib/python3.8/site-packages (from ray[serve]) (0.13.1)
# Collecting colorful; extra == "serve"
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 5.2 MB/s
# Collecting py-spy>=0.2.0; extra == "serve"
#   Downloading py_spy-0.3.11-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 47.9 MB/s
# Collecting opencensus; extra == "serve"
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 66.3 MB/s
# Collecting smart-open; extra == "serve"
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.4 MB/s
# Collecting uvicorn==0.16.0; extra == "serve"
#   Downloading uvicorn-0.16.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Collecting aiohttp-cors; extra == "serve"
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting starlette; extra == "serve"
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Requirement already satisfied, skipping upgrade: aiohttp>=3.7; extra == "serve" in /usr/local/lib/python3.8/site-packages (from ray[serve]) (3.7.4.post0)
# Collecting fastapi; extra == "serve"
#   Downloading fastapi-0.75.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.5 MB/s
# Collecting gpustat>=1.0.0b1; extra == "serve"
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 223 kB/s
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests->ray[serve]) (2021.10.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests->ray[serve]) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests->ray[serve]) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests->ray[serve]) (1.25.8)
# Requirement already satisfied, skipping upgrade: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[serve]) (5.2.0)
# Requirement already satisfied, skipping upgrade: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[serve]) (0.18.0)
# Requirement already satisfied, skipping upgrade: platformdirs<3,>=2 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[serve]) (2.5.2)
# Requirement already satisfied, skipping upgrade: distlib<1,>=0.3.1 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[serve]) (0.3.4)
# Requirement already satisfied, skipping upgrade: six<2,>=1.9.0 in /usr/local/lib/python3.8/site-packages (from virtualenv->ray[serve]) (1.14.0)
# Collecting google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"
#   Downloading google_api_core-2.7.2-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 56.8 MB/s
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.7 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.5 MB/s
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.10.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from starlette; extra == "serve"->ray[serve]) (4.1.1)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.8/site-packages (from aiohttp>=3.7; extra == "serve"->ray[serve]) (3.0.1)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/site-packages (from aiohttp>=3.7; extra == "serve"->ray[serve]) (5.2.0)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/site-packages (from aiohttp>=3.7; extra == "serve"->ray[serve]) (1.6.3)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.9.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.6 MB)
#      |████████████████████████████████| 12.6 MB 32.3 MB/s
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting psutil
#   Downloading psutil-5.9.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      |████████████████████████████████| 283 kB 50.2 MB/s
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.9 MB/s
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->ray[serve]) (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "serve"->ray[serve]) (2.6.6)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 49.9 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied, skipping upgrade: wcwidth>=0.1.4 in /usr/local/lib/python3.8/site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1; extra == "serve"->ray[serve]) (0.2.5)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "serve"->ray[serve]) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "serve"->ray[serve]) (4.8)
# Requirement already satisfied, skipping upgrade: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "serve"->ray[serve]) (5.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "serve"->ray[serve]) (0.4.8)
# Building wheels for collected packages: gpustat, nvidia-ml-py3
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=eb57dffe72872d473b2142a5c1b4b6309f05f8c3df1b8763ad4da636af55cd11
#   Stored in directory: /root/.cache/pip/wheels/80/87/f2/ed4a55705071f3671434e31c704883425b71bbc90b0c0cfa1e
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19189 sha256=20cd632314046ade7328644a686c2d835156148094d68a2d1c625efbba581f6b
#   Stored in directory: /root/.cache/pip/wheels/b9/b1/68/cb4feab29709d4155310d29a421389665dcab9eb3b679b527b
# Successfully built gpustat nvidia-ml-py3
# ERROR: fastapi 0.75.2 has requirement starlette==0.17.1, but you'll have starlette 0.19.1 which is incompatible.
# Installing collected packages: aiorwlock, colorful, py-spy, googleapis-common-protos, google-api-core, opencensus-context, opencensus, smart-open, h11, asgiref, uvicorn, aiohttp-cors, sniffio, anyio, starlette, pydantic, fastapi, nvidia-ml-py3, psutil, blessed, gpustat
# Successfully installed aiohttp-cors-0.7.0 aiorwlock-1.3.0 anyio-3.5.0 asgiref-3.5.0 blessed-1.19.1 colorful-0.5.4 fastapi-0.75.2 google-api-core-2.7.2 googleapis-common-protos-1.56.0 gpustat-1.0.0b1 h11-0.13.0 nvidia-ml-py3-7.352.0 opencensus-0.9.0 opencensus-context-0.1.2 psutil-5.9.0 py-spy-0.3.11 pydantic-1.9.0 smart-open-5.2.1 sniffio-1.2.0 starlette-0.19.1 uvicorn-0.16.0

# %%
import psutil
import ray
ray._private.utils.get_system_memory = lambda: psutil.virtual_memory().total

# %%
print(ray.__version__)
# Out:
# 1.12.0

# %%
ray.init()
# Out:
# RayContext(dashboard_url='', python_version='3.7.13', ray_version='1.12.0', ray_commit='f18fc31c7562990955556899090f8e8656b48d2d', address_info={'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-04-23_22-22-06_119635_408/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-04-23_22-22-06_119635_408/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2022-04-23_22-22-06_119635_408', 'metrics_export_port': 59556, 'gcs_address': '172.28.0.2:59277', 'address': '172.28.0.2:59277', 'node_id': 'ca6ec4449957422d6a8b9ca975ec7c13941f0de7144709bf911baf00'})

# %%
from gym import Env, utils
from gym.spaces import Box, MultiDiscrete
import numpy as np
import random

# default
NUM_ROWS = 5
NUM_COLUMNS = 5
NUM_MINES = 2

# cell values, non-negatives indicate number of neighboring mines
MINE = -1
CLOSED = -2
OPEN = 0


def int_to_char(i: int) -> chr:
    return chr(ord('@') + i + 1)


class MinesweeperEnv(Env):
    metadata = {"render.modes": ["ansi", "human"]}

    def __init__(self, env_config):
        """
        Create a minesweeper game
        :param rows: number of the board rows
        :param cols: number of the board columns
        :param mines: num mines on the board
        """
        self.rows = NUM_ROWS
        self.cols = NUM_COLUMNS
        self.mines = NUM_MINES

        self.observation_space = Box(low=-2, high=9, shape=(self.rows, self.cols), dtype=np.int8)
        self.action_space = MultiDiscrete((self.rows, self.cols))
        self.actions = []
        self.max_episode_steps = (self.rows * self.cols)

        self.reset()

    def count_surrounding_tiles(self, state: np.array, tile: int, x: int, y: int):
        """
        Return number of specific tiles in neighbour cells given an x-y coordinate
        :param state: visible board
        :param tile: tile type
        :param x: location
        :param y: location
        :return: int number of tiles
        """
        neighbour_tiles = 0
        for _x in range(x - 1, x + 2):
            for _y in range(y - 1, y + 2):
                if (_x >= 0) & (_x < self.rows) & (_y >= 0) & (_y < self.cols):
                    if state[_x, _y] == tile:
                        neighbour_tiles += 1
        return neighbour_tiles

    def open_surrounding_tiles(self, state: np.array, x: int, y: int):
        """
        Return number of mines in neighbour cells given an x-y coordinate
        :param state: visible board
        :param x: location
        :param y: location
        :return: next visible board
        """
        for _x in range(x - 1, x + 2):
            for _y in range(y - 1, y + 2):
                if (_x >= 0) & (_x < self.rows) & (_y >= 0) & (_y < self.cols):
                    if state[_x, _y] == CLOSED:
                        state[_x, _y] = self.count_surrounding_tiles(self.board, MINE, _x, _y)
                        if state[_x, _y] == OPEN:
                            state = self.open_surrounding_tiles(state, _x, _y)
        return state

    def get_next_state(self, state: np.array, x: int, y: int):
        """
        Get the next state
        :param state: visible board
        :param x: location
        :param y: location
        :return: next visible board and bool true if game over
        """
        game_over = False
        if self.board[x, y] == MINE:
            state[x, y] = MINE
            game_over = True
        else:
            state[x, y] = self.count_surrounding_tiles(self.board, MINE, x, y)
            if state[x, y] == OPEN:
                state = self.open_surrounding_tiles(state, x, y)
        self.current_board = state
        return state, game_over

    def next_step(self, state: np.array, x: int, y: int):
        """
        Get the next observation, reward and done status
        :param state: visible board
        :param x: location
        :param y: location
        :return: str of next visible board, the reward float, bool whether the game end or not
        """
        if self.max_episode_steps == len(self.actions):
            return state, -100, True
        
        if state[x, y] != CLOSED:
            return state, -1, False
        while True:
            #unknown = self.count_surrounding_tiles(state, CLOSED, x, y)
            state, game_over = self.get_next_state(state, x, y)
            if not game_over:
                if np.count_nonzero(state == CLOSED) == self.mines:
                    return state, 1000, True
                else:
                    return state, 10, False
            else:
                return state, -100, True

    def reset(self):
        """
        Resets the environment to an initial state and returns an initial observation. See gym.Env.reset()
        :return: the next board
        """
        self.board = np.zeros((self.rows, self.cols), dtype=np.int8)
        self.current_board = np.ones((self.rows, self.cols), dtype=np.int8) * CLOSED
        self.valid_actions = np.ones((self.rows, self.cols), dtype=np.bool8)
        self.actions.clear()

        mines_placed = 0
        while mines_placed < self.mines:
            rnd = random.randint(0, (self.rows * self.cols) - 1)
            x = int(rnd / self.rows)
            y = int(rnd % self.cols)
            if (x >= 0) & (x < self.rows) & (y >= 0) & (y < self.cols):
                if self.board[x, y] != MINE:
                    self.board[x, y] = MINE
                    mines_placed += 1
        return self.current_board

    def step(self, action):
        """
        Run one timestep of the environment's dynamics. See gym.Env.step()
        :param action: location index at 2d matrix
        :return: the reward for action, whether the game end or not and info
        """
        if isinstance(action, tuple):
            x = int(action[0])
            y = int(action[1])
        else:
            x = int(action / self.rows)
            y = int(action % self.cols)

        # test valid action
        if self.valid_actions[x, y] is False:
            raise Exception("Invalid action was selected! Action Filter: {}, "
                            "action taken: {}".format(self.valid_actions, action))

        next_state, reward, done = self.next_step(self.current_board, x, y)

        self.current_board = next_state
        self.valid_actions = (next_state == CLOSED)
        self.actions.append([x, y])

        # info['valid_actions'] = self.valid_actions.flatten()
        # info['num_actions'] = len(self.actions)

        return next_state, reward, done, {}

    def render(self, mode='human'):
        """
        Renders the environment. See gym.Env.render()
        """
        full_repr = ""
        for x in range(self.rows):
            full_repr += int_to_char(x)
            for y in range(self.cols):
                if self.current_board[x, y] == MINE:
                    full_repr += ' ' + utils.colorize('×', "red", highlight=True)
                elif self.current_board[x, y] == CLOSED:
                    full_repr += ' ▓'
                elif self.current_board[x, y] == OPEN:
                    if [x, y] in self.actions:
                        full_repr += ' ' + utils.colorize('░', "yellow", highlight=True)
                    else:
                        full_repr += ' ░'
                else:
                    char = '%s' % int(self.current_board[x, y])
                    if [x, y] in self.actions:
                        full_repr += ' ' + utils.colorize(char, "yellow", highlight=True)
                    else:
                        full_repr += ' ' + char
                if y != self.cols - 1:
                    full_repr += ' '
                    if y == (self.cols - 1):
                        full_repr += '\n'
            full_repr += '\n'
        full_repr += ' '
        for y in range(self.cols):
            full_repr += (' %s ' % y)
        full_repr += '\n'
        if mode == 'human':
            print(full_repr)
        return full_repr

# %%
from ray import tune

tune.run("PPO", config={
    "env": MinesweeperEnv,  
    "evaluation_duration": 2,
    "evaluation_duration_unit": 25,
    "num_cpus": 1,
    "num_gpus": 0,
})
# Out:
# 2022-04-23 23:37:04,589	WARNING callback.py:126 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# (scheduler +1h20m44s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:37:10 (running for 00:00:05.45)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:15 (running for 00:00:10.46)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:20 (running for 00:00:15.48)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:25 (running for 00:00:20.48)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:30 (running for 00:00:25.50)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:35 (running for 00:00:30.51)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h21m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:37:40 (running for 00:00:35.56)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:45 (running for 00:00:40.57)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:50 (running for 00:00:45.59)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:37:55 (running for 00:00:50.60)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:00 (running for 00:00:55.62)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:05 (running for 00:01:00.63)<br>Memory usage on this node: 3.2/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:10 (running for 00:01:05.65)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:38:15,265	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# (scheduler +1h21m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:38:15 (running for 00:01:10.66)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:20 (running for 00:01:15.70)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:25 (running for 00:01:20.70)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:30 (running for 00:01:25.72)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:35 (running for 00:01:30.72)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:40 (running for 00:01:35.81)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:45 (running for 00:01:40.81)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h22m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:38:50 (running for 00:01:45.83)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:38:55 (running for 00:01:50.84)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:00 (running for 00:01:55.87)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:05 (running for 00:02:00.87)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:10 (running for 00:02:05.89)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:39:15,503	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-23 23:39:15 (running for 00:02:10.90)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:20 (running for 00:02:15.92)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h23m4s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:39:25 (running for 00:02:20.93)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:30 (running for 00:02:25.94)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:35 (running for 00:02:30.95)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:40 (running for 00:02:35.96)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:45 (running for 00:02:40.97)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:50 (running for 00:02:45.98)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:39:55 (running for 00:02:50.99)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h23m39s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:40:00 (running for 00:02:56.01)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:05 (running for 00:03:01.01)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:10 (running for 00:03:06.03)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:40:15,644	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-23 23:40:15 (running for 00:03:11.04)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:20 (running for 00:03:16.07)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:25 (running for 00:03:21.08)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:30 (running for 00:03:26.10)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h24m14s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:40:35 (running for 00:03:31.10)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:40 (running for 00:03:36.13)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:45 (running for 00:03:41.13)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:50 (running for 00:03:46.15)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:40:55 (running for 00:03:51.16)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:00 (running for 00:03:56.18)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:05 (running for 00:04:01.18)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h24m49s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:41:10 (running for 00:04:06.20)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:41:15,818	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-23 23:41:15 (running for 00:04:11.22)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:20 (running for 00:04:16.24)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:25 (running for 00:04:21.24)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:30 (running for 00:04:26.26)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:35 (running for 00:04:31.27)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:40 (running for 00:04:36.28)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h25m24s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:41:45 (running for 00:04:41.29)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:50 (running for 00:04:46.30)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:41:55 (running for 00:04:51.31)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:00 (running for 00:04:56.33)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:05 (running for 00:05:01.34)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:10 (running for 00:05:06.36)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:42:15,970	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-23 23:42:15 (running for 00:05:11.36)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h25m59s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:42:20 (running for 00:05:16.39)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:26 (running for 00:05:21.40)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:31 (running for 00:05:26.41)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:36 (running for 00:05:31.41)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:41 (running for 00:05:36.43)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:46 (running for 00:05:41.43)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:42:51 (running for 00:05:46.45)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h26m34s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:42:56 (running for 00:05:51.45)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:01 (running for 00:05:56.47)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:06 (running for 00:06:01.47)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:11 (running for 00:06:06.49)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-23 23:43:16,102	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-23 23:43:16 (running for 00:06:11.50)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:21 (running for 00:06:16.52)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:26 (running for 00:06:21.52)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +1h27m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-23 23:43:31 (running for 00:06:26.54)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:36 (running for 00:06:31.55)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-23 23:43:41 (running for 00:06:36.57)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# ...
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:34:59 (running for 01:57:54.63)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:04 (running for 01:57:59.64)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +3h18m46s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-24 01:35:09 (running for 01:58:04.66)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:14 (running for 01:58:09.67)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:19 (running for 01:58:14.69)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:24 (running for 01:58:19.69)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:29 (running for 01:58:24.72)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-24 01:35:34,330	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-24 01:35:34 (running for 01:58:29.72)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:39 (running for 01:58:34.74)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +3h19m21s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-24 01:35:44 (running for 01:58:39.75)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:49 (running for 01:58:44.77)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:54 (running for 01:58:49.77)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:35:59 (running for 01:58:54.78)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:04 (running for 01:58:59.79)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:09 (running for 01:59:04.81)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:14 (running for 01:59:09.82)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +3h19m56s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-24 01:36:19 (running for 01:59:14.84)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:24 (running for 01:59:19.84)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:29 (running for 01:59:24.86)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# 2022-04-24 01:36:34,475	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 3.0 cpu and 0 gpu per trial, but the cluster only has 2.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==<br>Current time: 2022-04-24 01:36:34 (running for 01:59:29.87)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:39 (running for 01:59:34.89)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:44 (running for 01:59:39.89)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:49 (running for 01:59:44.91)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (scheduler +3h20m31s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# == Status ==<br>Current time: 2022-04-24 01:36:54 (running for 01:59:49.92)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:36:59 (running for 01:59:55.00)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-24 01:37:04 (running for 02:00:00.00)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.37 GiB heap, 0.0/3.69 GiB objects<br>Result logdir: /root/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MinesweeperEnv_481da_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>

# %%
while True:
    print(trainer.train())
